# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
link = "https://books.toscrape.com/catalogue/page-1.html"

# %%
res=requests.get(link)
soup= BeautifulSoup(res.text,"html.parser")

# %%
data = []

for sp in soup.find_all('li', class_= 'col-xs-6 col-sm-4 col-md-3 col-lg-3'):
        
    Img_link   = 'https://books.toscrape.com/' + sp.find('img').get('src')[3:]
    Book_link  = 'https://books.toscrape.com/catalogue/' + sp.find_all('a')[-1].get('href')
    Title      = sp.find_all('a')[-1].get('title')
    Rating     = sp.find('p').get('class')[-1]
    Price      = sp.find('p',class_ = 'price_color').text[2:]
    Stock      = sp.find('p', class_ = 'instock availability').text.strip()
    
    
    data.append([Title, Rating, Price, Stock, Book_link, Img_link])

# %%
len(data)
# Out:
# 20

# %%
fd=open(Title,'w', encoding='utf-8')
fd.write(Title)
fd.close()

# %%
Data=pd.DataFrame(data,columns=["Title","Rating","Price","Stock","Book_link","Img_link"])

# %%
Data.to_csv("Book_Scraper.csv",index=False)

# %%
df=pd.read_csv("Book_Scraper.csv")
df
# Out:
#                                                 Title Rating  Price     Stock  \
# 0                                A Light in the Attic  Three  51.77  In stock
# 1                                  Tipping the Velvet    One  53.74  In stock
# 2                                          Soumission    One  50.10  In stock
# 3                                       Sharp Objects   Four  47.82  In stock
# 4               Sapiens: A Brief History of Humankind   Five  54.23  In stock
# 5                                     The Requiem Red    One  22.65  In stock
# 6   The Dirty Little Secrets of Getting Your Dream...   Four  33.34  In stock
# 7   The Coming Woman: A Novel Based on the Life of...  Three  17.93  In stock
# 8   The Boys in the Boat: Nine Americans and Their...   Four  22.60  In stock
# 9                                     The Black Maria    One  52.15  In stock
# 10     Starving Hearts (Triangular Trade Trilogy, #1)    Two  13.99  In stock
# ...
